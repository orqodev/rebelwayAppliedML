# %%
import jax.numpy as jnp

# %%
def relu(x):
    return jnp.maximum(0, x)
def softmax(x):
    return jnp.exp(x) / jnp.sum(jnp.exp(x), axis=0)
def cross_entropy(x,y):
    return -jnp.sum(y * jnp.log(x))

# %%
x = jnp.arange(6.0)
print(relu(x))
print(softmax(x))
print(cross_entropy(softmax(x),x))
# Out:
# [0. 1. 2. 3. 4. 5.]
# [0.00426978 0.01160646 0.03154963 0.08576079 0.23312199 0.6336913 ]
# 26.8429

# %%
from jax import random

key = random.PRNGKey(0)
key, subkey = random.split(key)
print(subkey)
# Out:
# [ 928981903 3453687069]

# %%
x = random.normal(key, (2,3))

# %%
x = random.normal(key, (1_000_000,))
# %timeit relu(x)
# Out:
# 60.3 μs ± 806 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
from jax import jit

jitted_relu = jit(relu)
a = jitted_relu(x)
# %timeit relu(a)
# Out:
# 61.5 μs ± 1.75 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
def selu(x, alpha=1.67, lmbda=1.05):
    return lmbda * jnp.where(x > 0.0, x, alpha * jnp.exp(x) - alpha)

key = random.key(1000)
x = random.normal(key,(1_000_000,))
# %timeit selu(x).block_until_ready()
# Out:
# 369 μs ± 5.79 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
selu_jit = jit(selu)
_ = selu_jit(x)
# %timeit selu_jit(x).block_until_ready()
# Out:
# 48.2 μs ± 4.71 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
def mm(x,y):
    return jnp.dot(x,y)
@jit
def mm_jit(x,y):
    return jnp.dot(x,y)

# %%
a = random.normal(key,(1000,1000))
b = random.normal(key,(1000,1000))

# %timeit mm(a,b)
# Out:
# 52.9 μs ± 257 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit mm_jit(a,b)
# Out:
# 54 μs ± 1.87 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
